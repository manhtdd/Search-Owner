# %%
import pandas as pd

# Assuming you have loaded your CSV file into a DataFrame
df = pd.read_csv('~/Downloads/java.csv')

# Count the number of FALSE values in both 'found' and 'repo_empty' columns
false_count = ((df['found'] == True) & (df['empty_repo'] == False)).sum()

print("Number of FALSE values:", false_count)
# Out:
# Number of FALSE values: 157
